# %%
# %matplotlib inline
import pandas

import sklearn.linear_model

# %%
House = pandas.read_csv('/Users/nerenevaz/Desktop/SYDDAT7/SYD_DAT_7/lab/Week3/chicagohouseprices2.csv',index_col=0)

# %%
House
# Out:
#                                     Address Neighborhood           HouseType  \
# 0         2111 W Division St #5, Chicago IL  Wicker Park               Condo
# 1           1520 W Walton St #2, Chicago IL  Wicker Park               Condo
# 2              2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 3        1735 N Paulina St #314, Chicago IL  Wicker Park               Condo
# 4              1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5           1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 6            1440 N Wood St #2F, Chicago IL  Wicker Park               Condo
# 7            1137 N Wood St #F2, Chicago IL  Wicker Park               Condo
# 8               1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9           1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10               1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# ...

# %%
House.describe()
# Out:
# /Users/nerenevaz/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#               Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count  2.190000e+02  70.000000  219.000000     219.000000   219.000000
# mean   4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std    4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min    2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%    3.190000e+05        NaN    3.940000       8.000000     3.150000
# 50%    3.900000e+05        NaN    4.930000       9.000000     3.400000
# 75%    5.125000e+05        NaN    5.580000      10.000000     3.685000
# max    3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#               Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count  219.000000   219.000000     219.000000   219.000000    2.190000e+02
# ...

# %%
Estimate = pandas.DataFrame(House.EstimatedPrice)
Estimate
# Out:
#      EstimatedPrice
# 0          335790.0
# 1          376908.0
# 2          629300.0
# 3          297330.0
# 4          463644.0
# 5          813150.0
# 6          196667.5
# 7          445030.0
# 8          538696.0
# 9          463275.0
# 10         361782.0
# 11         334724.0
# 12         139468.0
# 13         680550.0
# 14         516987.0
# 15         282689.0
# 16         589410.0
# 17         644870.0
# 18         523230.0
# 19         945180.0
# 20        1087627.5
# 21         292320.0
# 22         449160.0
# 23         596820.0
# 24         369342.5
# 25         288365.0
# 26         364170.0
# 27         306950.0
# 28         357205.0
# 29         279405.0
# ..              ...
# 189        724680.0
# 190        643344.0
# 191        236530.0
# 192        290290.0
# 193        450800.0
# 194       1210300.0
# 195        332087.5
# 196        331985.0
# 197        292800.0
# 198        753720.0
# 199        635120.0
# 200        283682.0
# 201         84798.5
# ...

# %%
ransac = sklearn.linear_model.RANSACRegressor()

# %%
X=Estimate[['EstimatedPrice']]
y = House.Price

# %%
ransac.fit(X,y)
# Out:
# RANSACRegressor(base_estimator=None, is_data_valid=None, is_model_valid=None,
#         max_trials=100, min_samples=None, random_state=None,
#         residual_metric=None, residual_threshold=None, stop_n_inliers=inf,
#         stop_probability=0.99, stop_score=inf)

# %%
ransac = sklearn.linear_model.RANSACRegressor()

# %%
X = House[[ 'CrimeIndex' , 'MinutesToLoop' , 'MilesToLake' , 'Age' , 'LotSizeSqft' ,'HouseSizeSqft' , ]]
y = House.Price

# %%
ransac.fit(X,y)
# Out:
# RANSACRegressor(base_estimator=None, is_data_valid=None, is_model_valid=None,
#         max_trials=100, min_samples=None, random_state=None,
#         residual_metric=None, residual_threshold=None, stop_n_inliers=inf,
#         stop_probability=0.99, stop_score=inf)

# %%
ransac.estimator_.coef_
# Out:
# array([ -1.61939510e+04,  -6.54897345e+03,   4.29476658e+04,
#         -3.49653791e+02,   1.02234032e+02,   1.61016026e+01])

# %%
# %matplotlib inline

# %%
Predictions = ransac.predict(X)
Predictions
# Out:
# array([  338269.54756792,   375422.79704709,   603478.22149737,
#          303518.00384086,   453795.38926522,   769600.72056701,
#          212561.75655994,   436976.22039015,   521610.59622837,
#          453461.96961792,   361755.30223649,   337306.33525348,
#          160877.64513468,   649786.50584504,   501994.85876684,
#          290288.74352605,   567434.56368998,   617546.90417626,
#          507635.88548259,   888899.89680941,  1017612.07894823,
#          298991.08667829,   440707.99042636,   574130.06392445,
#          368586.79070109,   295417.44249107,   363913.04239303,
#          312210.40765403,   357619.63360314,   287321.39902268,
#          373161.14561836,   983612.76247424,  1034100.0871167 ,
#          405289.15561656,   318535.44161371,   522748.19876483,
#          480031.63012998,   524487.58310375,   626474.23782221,
#         2191242.46063348,   241350.14862743,   375546.58699744,
#          337717.46246086,   554639.92356583,   373929.18545632,
# ...

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.scatter(House.Price,House.EstimatedPrice)

# %%
(fig,ax) = matplotlib.pyplot.subplots()
ax.scatter(House.Price,House.EstimatedPrice, cmap=matplotlib.pylab.cm.PuOr , c=Predictions, label='Prices')
ax.set_xlabel = ('Actual price')
ax.set_ylabel = ('Predicted Price')
ax.legend(loc='best')

# %%
House
# Out:
#                                     Address Neighborhood           HouseType  \
# 0         2111 W Division St #5, Chicago IL  Wicker Park               Condo
# 1           1520 W Walton St #2, Chicago IL  Wicker Park               Condo
# 2              2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 3        1735 N Paulina St #314, Chicago IL  Wicker Park               Condo
# 4              1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5           1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 6            1440 N Wood St #2F, Chicago IL  Wicker Park               Condo
# 7            1137 N Wood St #F2, Chicago IL  Wicker Park               Condo
# 8               1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9           1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10               1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# ...

# %%
House1 = pandas.DataFrame(House.HouseSizeSqft,House.Bath)
House1.reindex()
House2 = pandas.DataFrame(House1)
House3 = House2.dropna()
House3
# Out:
#       HouseSizeSqft
# Bath
# 4.0          1840.0
# 2.0          3492.0
# 2.0          3492.0
# 2.0          3492.0
# 2.0          3492.0
# 2.0          3492.0
# 3.0             0.0
# 3.0             0.0
# 1.0             0.0
# 2.0          3492.0
# 2.0          3492.0
# 3.0             0.0
# 3.0             0.0
# 3.0             0.0
# 2.0          3492.0
# 2.0          3492.0
# 2.0          3492.0
# 2.0          3492.0
# 3.0             0.0
# 4.0          1840.0
# 2.0          3492.0
# 4.0          1840.0
# 2.0          3492.0
# 3.0             0.0
# 1.0             0.0
# 3.0             0.0
# 2.0          3492.0
# 1.0             0.0
# 3.0             0.0
# 2.0          3492.0
# ...             ...
# 2.0          3492.0
# 1.0             0.0
# 1.0             0.0
# 1.0             0.0
# 2.0          3492.0
# 2.0          3492.0
# 2.0          3492.0
# 4.0          1840.0
# 3.0             0.0
# 2.0          3492.0
# 1.0             0.0
# 1.0             0.0
# 4.0          1840.0
# ...

# %%
House2
# Out:
#       HouseSizeSqft
# Bath
# NaN             NaN
# NaN             NaN
#  4.0         1840.0
# NaN             NaN
#  2.0         3492.0
#  2.0         3492.0
# NaN             NaN
# NaN             NaN
#  2.0         3492.0
#  2.0         3492.0
#  2.0         3492.0
#  3.0            0.0
# NaN             NaN
#  3.0            0.0
#  1.0            0.0
# NaN             NaN
#  2.0         3492.0
#  2.0         3492.0
# NaN             NaN
#  3.0            0.0
#  3.0            0.0
# NaN             NaN
# NaN             NaN
#  3.0            0.0
# NaN             NaN
# NaN             NaN
#  2.0         3492.0
# NaN             NaN
# NaN             NaN
# NaN             NaN
# ...             ...
#  1.0            0.0
#  3.0            0.0
# NaN             NaN
# NaN             NaN
# NaN             NaN
#  3.0            0.0
# NaN             NaN
# NaN             NaN
# NaN             NaN
#  3.0            0.0
#  1.0            0.0
#  1.0            0.0
# NaN             NaN
# ...

# %%
House3.
# Out:
#        HouseSizeSqft
# count       70.00000
# mean      1604.40000
# std       1675.71962
# min          0.00000
# 25%          0.00000
# 50%        920.00000
# 75%       3492.00000
# max       3492.00000

# %%
House
# Out:
#                                     Address Neighborhood           HouseType  \
# 0         2111 W Division St #5, Chicago IL  Wicker Park               Condo
# 1           1520 W Walton St #2, Chicago IL  Wicker Park               Condo
# 2              2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 3        1735 N Paulina St #314, Chicago IL  Wicker Park               Condo
# 4              1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5           1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 6            1440 N Wood St #2F, Chicago IL  Wicker Park               Condo
# 7            1137 N Wood St #F2, Chicago IL  Wicker Park               Condo
# 8               1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9           1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10               1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# ...

# %%
dfhouse = pandas.DataFrame(House.Bath,House.HouseSizeSqft)
dfhouse
# Out:
#                Bath
# HouseSizeSqft
# 0               NaN
# 0               NaN
# 3492            NaN
# 0               NaN
# 1840            NaN
# 1628            NaN
# 0               NaN
# 0               NaN
# 1344            NaN
# 1760            NaN
# 2728            NaN
# 2405            NaN
# 0               NaN
# 3618            NaN
# 922             NaN
# 0               NaN
# 2544            NaN
# 2352            NaN
# 0               NaN
# 3461            NaN
# 2783            NaN
# 0               NaN
# 0               NaN
# 2656            NaN
# 0               NaN
# 0               NaN
# 1344            NaN
# 0               NaN
# 0               NaN
# 0               NaN
# ...             ...
# 392             NaN
# 3663            NaN
# 0               NaN
# 0               NaN
# 0               NaN
# 3043            NaN
# 0               NaN
# 0               NaN
# 0               NaN
# 2777            NaN
# 1214            NaN
# 1260            NaN
# ...

# %%
dfhouse1 = dfhouse.reindex

# %%
dfhouse1
# Out:
# <bound method DataFrame.reindex of                Bath
# HouseSizeSqft
# 0               NaN
# 0               NaN
# 3492            NaN
# 0               NaN
# 1840            NaN
# 1628            NaN
# 0               NaN
# 0               NaN
# 1344            NaN
# 1760            NaN
# 2728            NaN
# 2405            NaN
# 0               NaN
# 3618            NaN
# 922             NaN
# 0               NaN
# 2544            NaN
# 2352            NaN
# 0               NaN
# 3461            NaN
# 2783            NaN
# 0               NaN
# 0               NaN
# 2656            NaN
# 0               NaN
# 0               NaN
# 1344            NaN
# 0               NaN
# 0               NaN
# 0               NaN
# ...             ...
# 392             NaN
# 3663            NaN
# 0               NaN
# 0               NaN
# 0               NaN
# 3043            NaN
# 0               NaN
# 0               NaN
# 0               NaN
# 2777            NaN
# 1214            NaN
# ...

# %%
House
# Out:
#                                     Address Neighborhood           HouseType  \
# 0         2111 W Division St #5, Chicago IL  Wicker Park               Condo
# 1           1520 W Walton St #2, Chicago IL  Wicker Park               Condo
# 2              2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 3        1735 N Paulina St #314, Chicago IL  Wicker Park               Condo
# 4              1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5           1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 6            1440 N Wood St #2F, Chicago IL  Wicker Park               Condo
# 7            1137 N Wood St #F2, Chicago IL  Wicker Park               Condo
# 8               1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9           1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10               1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# ...

# %%
df1 = pandas.DataFrame({'HouseSizeSqft' :House.HouseSizeSqft , 'Bath' : House.Bath})
df1
# Out:
#      Bath  HouseSizeSqft
# 0     NaN              0
# 1     NaN              0
# 2     4.0           3492
# 3     NaN              0
# 4     2.0           1840
# 5     2.0           1628
# 6     NaN              0
# 7     NaN              0
# 8     2.0           1344
# 9     2.0           1760
# 10    2.0           2728
# 11    3.0           2405
# 12    NaN              0
# 13    3.0           3618
# 14    1.0            922
# 15    NaN              0
# 16    2.0           2544
# 17    2.0           2352
# 18    NaN              0
# 19    3.0           3461
# 20    3.0           2783
# 21    NaN              0
# 22    NaN              0
# 23    3.0           2656
# 24    NaN              0
# 25    NaN              0
# 26    2.0           1344
# 27    NaN              0
# 28    NaN              0
# 29    NaN              0
# ..    ...            ...
# 189   1.0            392
# 190   3.0           3663
# 191   NaN              0
# 192   NaN              0
# 193   NaN              0
# ...

# %%
df2 = df1.dropna()

# %%
df2
# Out:
#      Bath  HouseSizeSqft
# 2     4.0           3492
# 4     2.0           1840
# 5     2.0           1628
# 8     2.0           1344
# 9     2.0           1760
# 10    2.0           2728
# 11    3.0           2405
# 13    3.0           3618
# 14    1.0            922
# 16    2.0           2544
# 17    2.0           2352
# 19    3.0           3461
# 20    3.0           2783
# 23    3.0           2656
# 26    2.0           1344
# 31    2.0           2580
# 32    2.0           1290
# 33    2.0           2763
# 35    3.0           1983
# 37    4.0           2856
# 38    2.0           2279
# 39    4.0           6422
# 43    2.0           2183
# 45    3.0           4125
# 46    1.0           2040
# 49    3.0           2403
# 52    2.0           1089
# 53    1.0            861
# 57    3.0           2997
# 58    2.0           1436
# ..    ...            ...
# 91    2.0           1512
# 92    1.0           1996
# 93    1.0           1958
# 101   1.0            900
# 102   2.0           2420
# ...

# %%
A =
