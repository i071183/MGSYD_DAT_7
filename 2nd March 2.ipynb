# %%
import requests

# %%
url = 'http://www.statestreet.com/home.html'
r = requests.get(url)
if r.status_code == 200:
    print r.text
# Out:
# <!doctype html>
# <!-- [if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif] -->
# <!-- [if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif] -->
# <!-- [if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif] -->
# <!-- [if gt IE 8]><!-->
# <html class="no-js" lang="en">
# <!--<![endif]-->
#
#
#
#
#
#
#
# <head>
# <title>
#
#         Home | State Street Corporation
#     </title>
#
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
#
# <meta http-equiv="cleartype" content="on">
# <meta name="HandheldFriendly" content="True">
# <meta name="MobileOptimized" content="320">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# // Global Strings and all Ajax or non Ajax Paths which will be used in JS code
# var sapeLibMod = sapeLibMod || {};
#
# /**
# * Extending sapeLibMod Object with all the String messages which will be used to show messages through JS.
# */
# ...

# %%
import requests

# %%
url = 'https://en.m.wikipedia.org/w/index.php?title=Main_Page&mobileaction=toggle_view_mobile'

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
import bs4
soup = bs4.BeautifulSoup(r.text, 'lxml')

# %%
soup.find_all('h2')
# Out:
# [<h2>Today's featured article</h2>,
#  <h2>In the news</h2>,
#  <h2><img alt="Wikipedia" height="18" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" width="116"/></h2>]

# %%
soup.find_all('a')[2]
# Out:
# <a href="/wiki/Burning_Rangers" title="Burning Rangers">Burning Rangers</a>

# %%
requests.get('')

# %%
soup.find_all('h2')[1].parent
# Out:
# <div id="mainpage"><h2>Today's featured article</h2><div id="mp-tfa" style="padding:2px 5px"><i><b><a href="/wiki/Burning_Rangers" title="Burning Rangers">Burning Rangers</a></b></i> is a 1998 <a href="/wiki/3D_computer_graphics" title="3D computer graphics">3D</a> <a href="/wiki/Action_game" title="Action game">action</a> video game developed by <a href="/wiki/Sonic_Team" title="Sonic Team">Sonic Team</a> and published by <a href="/wiki/Sega" title="Sega">Sega</a> for the <a href="/wiki/Sega_Saturn" title="Sega Saturn">Sega Saturn</a>. The game is set in a futuristic society threatened by frequent fires. Players control one of an elite group of <a href="/wiki/Firefighter" title="Firefighter">firefighters</a>, the Burning Rangers, who extinguish the fires and rescue civilians from burning buildings. Most of the tasks the players complete are centred around collecting energy crystals used to transport civilians to safety. Development began shortly after the release of <i><a class="mw-
# ...

# %%
in_the_news = soup.find_all('h2')[1]
in_the_news
# Out:
# <h2>In the news</h2>

# %%
in_the_news.next_sibling.find('li')
# Out:
# <li>The discovery of the <b><a href="/wiki/Leekfrith_torcs" title="Leekfrith torcs">Leekfrith torcs</a></b> <i>(pictured)</i>, believed to be the oldest <a href="/wiki/Iron_Age" title="Iron Age">Iron Age</a> gold jewellery found in Britain, is announced.</li>

# %%
in_the_news.next_sibling.find('li').text
# Out:
# u'The discovery of the Leekfrith torcs (pictured), believed to be the oldest Iron Age gold jewellery found in Britain, is announced.'

# %%
url = 'http://pokeapi.co/api/v2/move/double-slap'
r= requests.get(url)
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {u'accuracy': 85,
#  u'contest_combos': {u'normal': {u'use_after': [{u'name': u'pound',
#      u'url': u'http://pokeapi.co/api/v2/move/1/'},
#     {u'name': u'rain-dance', u'url': u'http://pokeapi.co/api/v2/move/240/'}],
#    u'use_before': None},
#   u'super': {u'use_after': None, u'use_before': None}},
#  u'contest_effect': {u'url': u'http://pokeapi.co/api/v2/contest-effect/10/'},
#  u'contest_type': {u'name': u'tough',
#   u'url': u'http://pokeapi.co/api/v2/contest-type/5/'},
#  u'damage_class': {u'name': u'physical',
#   u'url': u'http://pokeapi.co/api/v2/move-damage-class/2/'},
#  u'effect_chance': None,
#  u'effect_changes': [],
#  u'effect_entries': [{u'effect': u'Inflicts regular damage.  Hits 2\u20135 times in one turn.\n\nHas a 3/8 chance each to hit 2 or 3 times, and a 1/8 chance each to hit 4 or 5 times.  Averages to 3 hits per use.',
#    u'language': {u'name': u'en',
#     u'url': u'http://pokeapi.co/api/v2/language/9/'},
# ...

# %%
r.json()['accuracy']
# Out:
# 85

# %%
r.json()['effect_entries'][0]['effect']
# Out:
# u'Inflicts regular damage.  Hits 2\u20135 times in one turn.\n\nHas a 3/8 chance each to hit 2 or 3 times, and a 1/8 chance each to hit 4 or 5 times.  Averages to 3 hits per use.'
