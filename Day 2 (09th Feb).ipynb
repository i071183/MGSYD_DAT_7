# %%
import pandas

# %%
import pandas

# %%
fatalities = pandas.Series(index=['Australia','Albania', 'Libya' , 'Monaco' , 'Burkina Faso'] , data = [5.4, 15.1 , 73.4, "-", 30])

# %%
fatalities
# Out:
# Australia        5.4
# Albania         15.1
# Libya           73.4
# Monaco             -
# Burkina Faso      30
# dtype: object

# %%
fatalities.str.isalpha()
# Out:
# Australia         NaN
# Albania           NaN
# Libya             NaN
# Monaco          False
# Burkina Faso      NaN
# dtype: object

# %%
fatalities.str.isalnum
# Out:
# <bound method StringMethods.<lambda> of <pandas.core.strings.StringMethods object at 0x111c37390>>

# %%
fatalities == "-"
# Out:
# Australia       False
# Albania         False
# Libya           False
# Monaco           True
# Burkina Faso    False
# dtype: bool

# %%
data_invalid = fatalities == "-"
fatalities[data_invalid]
# Out:
# Monaco    -
# dtype: object

# %%
fatalities[data_invalid] = 0

# %%
fatalities.dtype
# Out:
# dtype('O')

# %%
fatalities = fatalities.replace("-" , 0)

# %%
fatalities.min()
# Out:
# 0.0

# %%
fatalities.idxmin()
# Out:
# 'Monaco'

# %%
fatalities.idxma()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-683f18c00fcb> in <module>()
# ----> 1 fatalities.idxma()
#
# /Users/nerenevaz/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'idxma'

# %%
fatalities.idxmax()
# Out:
# 'Libya'

# %%
fatalities.mean(), fatalities.median(), fatalities.std()
# Out:
# (24.78, 15.1, 29.472393862731952)

# %%
population = pandas.Series(index = ['Australia' ,'Burkina Faso' , 'Libya'] ,data =[24000000 , 19000000, 6300000])

# %%
population
# Out:
# Australia       24000000
# Burkina Faso    19000000
# Libya            6300000
# dtype: int64

# %%
population * fatalities /100000
# Out:
# Albania            NaN
# Australia       1296.0
# Burkina Faso    5700.0
# Libya           4624.2
# Monaco             NaN
# dtype: float64

# %%
fatality_count = (population * fatalities /100000).astype(float)
fatality_count
# Out:
# Albania            NaN
# Australia       1296.0
# Burkina Faso    5700.0
# Libya           4624.2
# Monaco             NaN
# dtype: float64

# %%
fatality_count.isnull()
# Out:
# Albania          True
# Australia       False
# Burkina Faso    False
# Libya           False
# Monaco           True
# dtype: bool

# %%
fatality_count[fatality_count.notnull()]
# Out:
# Australia       1296.0
# Burkina Faso    5700.0
# Libya           4624.2
# dtype: float64

# %%
fatality_count * fatalities[]
# Out:
#   File "<ipython-input-27-1fd374e294f2>", line 1
#     fatality_count * fatalities[]
#                                 ^
# SyntaxError: invalid syntax

# %%
fatality_count*fatality_count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-87ae37890369> in <module>()
# ----> 1 fatality_count*fatality_count()
#
# TypeError: 'Series' object is not callable

# %%
list_of_tables = pandas.read_html('http://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population', header=0 , index_col=1)

# %%
# !pip install html5lib
# Out:
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install BeautifulSoup4
# Out:
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
list_of_tables = pandas.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population', header=0 , index_col=1)

# %%
--upgrade pip
# Out:
#   File "<ipython-input-33-191f382dcbd8>", line 1
#     --upgrade pip
#                 ^
# SyntaxError: invalid syntax

# %%
list_of_tables = pandas.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population', header=0 , index_col=1)

# %%
len(list_of_tables)
# Out:
# 3

# %%
populations = list_of_tables[1]

# %%
populations
# Out:
#                                                   Rank  Population  \
# Country (or dependent territory)
# China[Note 2]                                        1  1381450000
# India                                                2  1311740000
# United States[Note 3]                                3   324503000
# Indonesia                                            4   260581000
# Brazil                                               5   207074000
# Pakistan                                             6   196310000
# Nigeria                                              7   186988000
# Bangladesh                                           8   161913000
# Russia[Note 4]                                       9   146838993
# Japan                                               10   126860000
# Mexico                                              11   122273000
# Philippines                                         12   103743000
# ...

# %%
sydtrains = pandas.read_csv('/Users/nerenevaz/Desktop/SYDDAT7/SYD_DAT_7/data/sydtrains.csv',index_col=1, thousands= ',')

# %%
sydtrains
# Out:
#                                                LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                         CBD  2014        6/05/2014
# Town Hall                                       CBD  2014        7/05/2014
# Wynyard                                         CBD  2014       20/05/2014
# Parramatta                                  Western  2014       19/11/2014
# North Sydney                            North Shore  2014       19/08/2014
# Redfern                                         CBD  2014        1/05/2014
# Chatswood                               North Shore  2014       19/08/2014
# Bondi Junction                      Eastern Suburbs  2014        2/09/2014
# Strathfield                              Inner West  2014        9/09/2014
# Circular Quay                                   CBD  2014       22/05/2014
# Martin Place                                    CBD  2014       27/05/2014
# ...

# %%
sydtrains[LINE]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-843df0dd156f> in <module>()
# ----> 1 sydtrains[LINE]
#
# NameError: name 'LINE' is not defined

# %%
sydtrains.IN_0200_0600
# Out:
# STATION
# Central                   940
# Town Hall                 880
# Wynyard                   590
# Parramatta                660
# North Sydney              270
# Redfern                   250
# Chatswood                 210
# Bondi Junction            210
# Strathfield               190
# Circular Quay             200
# Martin Place              200
# Hurstville                160
# St Leonards               170
# Blacktown                 190
# Burwood                   140
# Kings Cross               120
# Hornsby                   210
# Ashfield                  100
# Kogarah                    90
# Lidcombe                  100
# Auburn                    130
# Museum                    100
# Epping                    170
# Macquarie University      100
# St James                  100
# Rockdale                   90
# Cabramatta                150
# Bankstown                  80
# Liverpool                 150
# Sutherland                140
# ...

# %%
len(sydtrains)
# Out:
# 3367

# %%
sydtrains.count()
# Out:
# LINE                3367
# YEAR                3367
# SURVEY_DATE_USED    3367
# WHETHER_SURVEYED    3367
# IN_0200_0600        3367
# OUT_0200_0600       3367
# IN_0600_0930        3367
# OUT_0600_0930       3367
# IN_0930_1500        3367
# OUT_0930_1500       3367
# IN_1500_1830        3367
# OUT_1500_1830       3367
# IN_1830_0200        3367
# OUT_1830_0200       3367
# IN_24_HOURS         3367
# OUT_24_HOURS        3367
# RANK                3367
# STATION_SORT_ID     3367
# dtype: int64

# %%
trains2014 = sydtrains[sydtrains.YEAR == 2014]
trains2014
# Out:
#                                                  LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                           CBD  2014        6/05/2014
# Town Hall                                         CBD  2014        7/05/2014
# Wynyard                                           CBD  2014       20/05/2014
# Parramatta                                    Western  2014       19/11/2014
# North Sydney                              North Shore  2014       19/08/2014
# Redfern                                           CBD  2014        1/05/2014
# Chatswood                                 North Shore  2014       19/08/2014
# Bondi Junction                        Eastern Suburbs  2014        2/09/2014
# Strathfield                                Inner West  2014        9/09/2014
# Circular Quay                                     CBD  2014       22/05/2014
# Martin Place                                      CBD  2014       27/05/2014
# ...

# %%
sydtrains.LINE.unique()
# Out:
# array(['CBD', 'Western', 'North Shore', 'Eastern Suburbs', 'Inner West',
#        'Illawarra', 'South', 'Northern via Strathfield',
#        'Northern via Macquarie Park', 'Bankstown', 'Airport', 'East Hills',
#        'Central Coast', 'Olympic Park', 'South Coast', 'Blue Mountains',
#        'Newcastle', 'Hunter', 'Carlingford', 'Southern Highlands'], dtype=object)

# %%
sydtrains[sydtrains.LINE.str.contains('C')].LINE.unique()
# Out:
# array(['CBD', 'Central Coast', 'South Coast', 'Carlingford'], dtype=object)

# %%
sydtrains.index.unique()
# Out:
# array(['Central', 'Town Hall', 'Wynyard', 'Parramatta', 'North Sydney',
#        'Redfern', 'Chatswood', 'Bondi Junction', 'Strathfield',
#        'Circular Quay', 'Martin Place', 'Hurstville', 'St Leonards',
#        'Blacktown', 'Burwood', 'Kings Cross', 'Hornsby', 'Ashfield',
#        'Kogarah', 'Lidcombe', 'Auburn', 'Museum', 'Epping',
#        'Macquarie University', 'St James', 'Rockdale', 'Cabramatta',
#        'Bankstown', 'Liverpool', 'Sutherland', 'Fairfield', 'Westmead',
#        'Penrith', 'Mount Druitt', 'Edgecliff', 'Mascot', 'Eastwood',
#        'Milsons Point', 'Newtown', 'Campsie', 'Seven Hills', 'Rhodes',
#        'Domestic Airport', 'Granville', 'West Ryde', 'Campbelltown',
#        'Green Square', 'Gordon', 'Sydenham', 'Merrylands', 'Artarmon',
#        'Gosford', 'Glenfield', 'Turramurra', 'Lakemba', 'St Marys',
#        'Wolli Creek', 'Woy Woy', 'Mortdale', 'Revesby', 'Riverwood',
#        'Olympic Park', 'Lindfield', 'Marrickville', 'Macquarie Park',
# ...

# %%
trains2014.IN_0930_1500.dtype
# Out:
# dtype('int64')

# %%
trains2014.dtypes
# Out:
# LINE                object
# YEAR                 int64
# SURVEY_DATE_USED    object
# WHETHER_SURVEYED    object
# IN_0200_0600         int64
# OUT_0200_0600        int64
# IN_0600_0930         int64
# OUT_0600_0930        int64
# IN_0930_1500         int64
# OUT_0930_1500        int64
# IN_1500_1830         int64
# OUT_1500_1830        int64
# IN_1830_0200         int64
# OUT_1830_0200        int64
# IN_24_HOURS          int64
# OUT_24_HOURS         int64
# RANK                 int64
# STATION_SORT_ID      int64
# dtype: object

# %%
trains2014.IN_24_HOURS
# Out:
# STATION
# Central                     97110
# Town Hall                   89620
# Wynyard                     60200
# Parramatta                  34960
# North Sydney                28610
# Redfern                     25680
# Chatswood                   22200
# Bondi Junction              21880
# Strathfield                 20710
# Circular Quay               20630
# Martin Place                20630
# Hurstville                  18290
# St Leonards                 17590
# Blacktown                   16560
# Burwood                     14990
# Kings Cross                 12870
# Hornsby                     12250
# Ashfield                    11200
# Kogarah                     11100
# Lidcombe                    10910
# Auburn                      10890
# Museum                      10860
# Epping                      10570
# Macquarie University        10090
# St James                     9850
# Rockdale                     9640
# Cabramatta                   8730
# ...

# %%
trains2014.IN_24_HOURS.idxmax()
# Out:
# 'Central'

# %%
trains2014.IN_24_HOURS.idxmin()
# Out:
# 'Bell'

# %%
trains2014.IN_24_HOURS.min(0)
# Out:
# 0

# %%
trains2014.IN_24_HOURS.min()
# Out:
# 0

# %%
trains2014[['IN_200_600' , 'IN_24_HOURS']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-59cd8d7547be> in <module>()
# ----> 1 trains2014[['IN_200_600' , 'IN_24_HOURS']]
#
# /Users/nerenevaz/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# /Users/nerenevaz/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2033             return self.take(indexer, axis=0, convert=False)
#    2034         else:
# -> 2035             indexer = self.ix._convert_to_indexer(key, axis=1)
# ...

# %%
trains2014.loc['Central']
# Out:
# LINE                      CBD
# YEAR                     2014
# SURVEY_DATE_USED    6/05/2014
# WHETHER_SURVEYED          Yes
# IN_0200_0600              940
# OUT_0200_0600             920
# IN_0600_0930            10390
# OUT_0600_0930           42070
# IN_0930_1500            21400
# OUT_0930_1500           30150
# IN_1500_1830            45370
# OUT_1500_1830           16270
# IN_1830_0200            19010
# OUT_1830_0200            7700
# IN_24_HOURS             97110
# OUT_24_HOURS            97110
# RANK                        1
# STATION_SORT_ID           101
# Name: Central, dtype: object

# %%
trains2014.describe()
# Out:
#          YEAR  IN_0200_0600  OUT_0200_0600  IN_0600_0930  OUT_0600_0930  \
# count   308.0    308.000000     308.000000    308.000000     308.000000
# mean   2014.0     52.142857      33.084416   1176.266234    1130.422078
# std       0.0    107.324369      90.671936   1626.940742    4482.948456
# min    2014.0      0.000000       0.000000      0.000000       0.000000
# 25%    2014.0     10.000000       0.000000     97.500000      20.000000
# 50%    2014.0     20.000000      10.000000    520.000000     150.000000
# 75%    2014.0     50.000000      30.000000   1650.000000     602.500000
# max    2014.0    940.000000     920.000000  10390.000000   43210.000000
#
#        IN_0930_1500  OUT_0930_1500  IN_1500_1830  OUT_1500_1830  IN_1830_0200  \
# count    308.000000     308.000000    308.000000     308.000000    308.000000
# mean     777.954545     809.545455   1226.818182    1131.785714    385.194805
# std     1901.729550    2470.684364   4508.392060    1869.717983   1835.041549
# ...

# %%
trains2014.LINE.value_counts
# Out:
# <bound method Series.value_counts of STATION
# Central                                             CBD
# Town Hall                                           CBD
# Wynyard                                             CBD
# Parramatta                                      Western
# North Sydney                                North Shore
# Redfern                                             CBD
# Chatswood                                   North Shore
# Bondi Junction                          Eastern Suburbs
# Strathfield                                  Inner West
# Circular Quay                                       CBD
# Martin Place                                        CBD
# Hurstville                                    Illawarra
# St Leonards                                 North Shore
# Blacktown                                       Western
# Burwood                                      Inner West
# Kings Cross                             Eastern Suburbs
# ...
